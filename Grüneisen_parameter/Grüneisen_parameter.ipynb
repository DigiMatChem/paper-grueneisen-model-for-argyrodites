# %%
from pymatgen.io.phonopy import get_gruneisen_ph_bs_symm_line,get_gruneisenparameter
import pandas as pd
import scipy.constants as const
import numpy as np

# %%
ge=get_gruneisenparameter(gruneisen_path='Ge/gruneisen_mesh.yaml')

# %%
si=get_gruneisenparameter(gruneisen_path='Si/gruneisen_mesh.yaml')

# %%
RT=get_gruneisenparameter(gruneisen_path='RT/gruneisen_mesh.yaml')

# %%
LT=get_gruneisenparameter(gruneisen_path='LT/gruneisen_mesh.yaml')

# %%
print(si.average_gruneisen(limit_frequencies=None, t=300))
print(si.average_gruneisen(limit_frequencies='acoustic', t=300))
print(si.average_gruneisen(limit_frequencies='debye', t=300))
# Out:
# 1.6986795765451452
# 1.3323457183071914
# 2.5042082430846255

# %%
print(ge.average_gruneisen(limit_frequencies=None, t=300))
print(ge.average_gruneisen(limit_frequencies='acoustic', t=300))
print(ge.average_gruneisen(limit_frequencies='debye', t=300))
# Out:
# 1.5763703992976514
# 2.1750686875587033
# 2.3982041915497048

# %%
print(RT.average_gruneisen(limit_frequencies=None, t=300))
print(RT.average_gruneisen(limit_frequencies='acoustic', t=300))
print(RT.average_gruneisen(limit_frequencies='debye', t=300))
# Out:
# 1.4439842272660675
# 1.704427657451298
# 1.8802293187373642

# %%
print(LT.average_gruneisen(limit_frequencies=None, t=300))
print(LT.average_gruneisen(limit_frequencies='acoustic', t=300))
print(LT.average_gruneisen(limit_frequencies='debye', t=300))
# Out:
# 1.5470980026514363
# 1.790363585226812
# 2.025023106161897

# %%
print(si.average_gruneisen(limit_frequencies=None))
print(si.average_gruneisen(limit_frequencies='acoustic'))
print(si.average_gruneisen(limit_frequencies='debye'))
# Out:
# 1.9417749304776337
# 1.4863047341433118
# 2.535032100886041

# %%
print(ge.average_gruneisen(limit_frequencies=None))
print(ge.average_gruneisen(limit_frequencies='acoustic'))
print(ge.average_gruneisen(limit_frequencies='debye'))
# Out:
# 1.8198234868357415
# 2.562027164396893
# 2.426252811751241

# %%
print(RT.average_gruneisen(limit_frequencies=None))
print(RT.average_gruneisen(limit_frequencies='acoustic'))
print(RT.average_gruneisen(limit_frequencies='debye'))
# Out:
# 1.6111158045073481
# 1.9393796594505646
# 1.8877160292257915

# %%
print(LT.average_gruneisen(limit_frequencies=None))
print(LT.average_gruneisen(limit_frequencies='acoustic'))
print(LT.average_gruneisen(limit_frequencies='debye'))
# Out:
# 1.6747569211258924
# 1.9598630101444272
# 2.02597216793887
